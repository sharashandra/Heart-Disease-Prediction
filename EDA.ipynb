# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
sns.set(style="whitegrid")

# %%
df = pd.read_csv(r'C:\Users\shara\OneDrive\Desktop\ClassNotes FSDS\30th- Seaborn, Eda practicle\EDA\heart.csv')

# %%
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %% [markdown]
# Dataset description
# The dataset contains several columns which are as follows -
#
# age : age in years
# sex : (1 = male; 0 = female)
# cp : chest pain type
# trestbps : resting blood pressure (in mm Hg on admission to the hospital)
# chol : serum cholestoral in mg/dl
# fbs : (fasting blood sugar > 120 mg/dl) (1 = true; 0 = false)
# restecg : resting electrocardiographic results
# thalach : maximum heart rate achieved
# exang : exercise induced angina (1 = yes; 0 = no)
# oldpeak : ST depression induced by exercise relative to rest
# slope : the slope of the peak exercise ST segment
# ca : number of major vessels (0-3) colored by flourosopy
# thal : 3 = normal; 6 = fixed defect; 7 = reversable defect
# target : 1 or 0

# %%
df.shape
# Out:
# (303, 14)

# %%
df.dtypes
# Out:
# age           int64
# sex           int64
# cp            int64
# trestbps      int64
# chol          int64
# fbs           int64
# restecg       int64
# thalach       int64
# exang         int64
# oldpeak     float64
# slope         int64
# ca            int64
# thal          int64
# target        int64
# dtype: object

# %%
len(df)
# Out:
# 303

# %%
df.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       303 non-null    int64
#  1   sex       303 non-null    int64
#  2   cp        303 non-null    int64
#  3   trestbps  303 non-null    int64
#  4   chol      303 non-null    int64
#  5   fbs       303 non-null    int64
#  6   restecg   303 non-null    int64
#  7   thalach   303 non-null    int64
#  8   exang     303 non-null    int64
#  9   oldpeak   303 non-null    float64
#  10  slope     303 non-null    int64
#  11  ca        303 non-null    int64
#  12  thal      303 non-null    int64
#  13  target    303 non-null    int64
# dtypes: float64(1), int64(13)
# memory usage: 33.3 KB

# %%
df.isna().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %%
df.describe()
# Out:
#               age         sex          cp    trestbps        chol         fbs  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    54.366337    0.683168    0.966997  131.623762  246.264026    0.148515
# std      9.082101    0.466011    1.032052   17.538143   51.830751    0.356198
# min     29.000000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     47.500000    0.000000    0.000000  120.000000  211.000000    0.000000
# 50%     55.000000    1.000000    1.000000  130.000000  240.000000    0.000000
# 75%     61.000000    1.000000    2.000000  140.000000  274.500000    0.000000
# max     77.000000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope          ca  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean     0.528053  149.646865    0.326733    1.039604    1.399340    0.729373
# ...

# %%
df['target']
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 298    0
# 299    0
# 300    0
# 301    0
# 302    0
# Name: target, Length: 303, dtype: int64

# %%
df.target.value_counts()
# Out:
# target
# 1    165
# 0    138
# Name: count, dtype: int64

# %%
df.target.unique()
# Out:
# array([1, 0], dtype=int64)

# %%
df.target.nunique()
# Out:
# 2

# %%
f, axs = plt.subplots(figsize = (10, 6))
axs = sns.countplot(data = df, x = 'target', palette='Set1')
plt.show()

# %%
df.groupby('sex')['target'].value_counts()
# Out:
# sex  target
# 0    1          72
#      0          24
# 1    0         114
#      1          93
# Name: count, dtype: int64

# %%
f, axs = plt.subplots(figsize = (10, 6))
axs = sns.countplot(data = df, x = 'sex', hue = 'target')
plt.show()

# %%
sns.catplot(data = df,x = 'target', col = 'sex', kind = 'count', height = 5, aspect = 1, palette='Set1')

# %%
f, ax = plt.subplots(figsize = (8, 6))
ax = sns.countplot(data = df, y = 'target', hue = 'sex')

# %%
f, ax = plt.subplots(figsize = (10,8))
ax = sns.countplot(data = df, x = 'target', hue = 'sex', palette= 'Set3')
plt.show()

# %%
f, ax = plt.subplots(figsize = (7, 5))
ax = sns.countplot(data = df, x = 'target', facecolor = (0,0,0,0), linewidth = 5, edgecolor = sns.color_palette('dark', 3))
plt.show()

# %%
f, ax = plt.subplots(figsize = (7,5))
ax = sns.countplot(data = df, x = 'target', hue = 'fbs')

# %%
f, ax = plt.subplots(figsize = (7, 5))
ax = sns.countplot(data = df, x = 'target', hue = 'exang')
plt.show()

# %%
df.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
# Bi-Variate Analysis

# %%
corelation = df.corr()

# %%
corelation['target'].sort_values(ascending=False)
# Out:
# target      1.000000
# cp          0.433798
# thalach     0.421741
# slope       0.345877
# restecg     0.137230
# fbs        -0.028046
# chol       -0.085239
# trestbps   -0.144931
# age        -0.225439
# sex        -0.280937
# thal       -0.344029
# ca         -0.391724
# oldpeak    -0.430696
# exang      -0.436757
# Name: target, dtype: float64

# %%
f, ax = plt.subplots(figsize= (16, 12))
ax = sns.heatmap(data = corelation, annot = True, square= True)
ax.set_xticklabels(ax.get_xticklabels(), rotation = 90)
ax.set_yticklabels(ax.get_yticklabels(), rotation = 30)
plt.show()

# %%
df.cp.unique()
# Out:
# array([3, 2, 1, 0], dtype=int64)

# %%
df.cp.nunique()
# Out:
# 4

# %%
df['cp'].value_counts()
# Out:
# cp
# 0    143
# 2     87
# 1     50
# 3     23
# Name: count, dtype: int64

# %%
f, ax = plt.subplots(figsize = (8, 6))
ax = sns.countplot(data = df, x = 'cp')
plt.show()

# %%
df.groupby('cp')['target'].value_counts()
# Out:
# cp  target
# 0   0         104
#     1          39
# 1   1          41
#     0           9
# 2   1          69
#     0          18
# 3   1          16
#     0           7
# Name: count, dtype: int64

# %%
f, ax = plt.subplots(figsize = (8, 6))
ax = sns.countplot(data = df, x = 'cp', hue = 'target')
plt.show()

# %%
sns.catplot(data = df, x = 'target', col = 'cp', kind = 'count', height = 8, aspect = 1, palette='Set1')

# %%
df['thalach'].unique()
# Out:
# array([150, 187, 172, 178, 163, 148, 153, 173, 162, 174, 160, 139, 171,
#        144, 158, 114, 151, 161, 179, 137, 157, 123, 152, 168, 140, 188,
#        125, 170, 165, 142, 180, 143, 182, 156, 115, 149, 146, 175, 186,
#        185, 159, 130, 190, 132, 147, 154, 202, 166, 164, 184, 122, 169,
#        138, 111, 145, 194, 131, 133, 155, 167, 192, 121,  96, 126, 105,
#        181, 116, 108, 129, 120, 112, 128, 109, 113,  99, 177, 141, 136,
#         97, 127, 103, 124,  88, 195, 106,  95, 117,  71, 118, 134,  90],
#       dtype=int64)

# %%
df['thalach'].nunique()
# Out:
# 91

# %%
f,ax = plt.subplots(figsize = (10, 6))
ax = sns.distplot(df['thalach'], bins = 10)
plt.show()

# %%
f, ax = plt.subplots(figsize = (10, 6))
x = df['thalach']
x = pd.Series(x, name = 'Thalach Variable')
ax = sns.distplot(x, bins = 10)
plt.show()

# %%
f,ax = plt.subplots(figsize = (10, 6))
ax = sns.distplot(df['thalach'], bins = 10, vertical = True)
plt.show()

# %%
f, ax = plt.subplots(figsize = (10, 6))
x = df['thalach']
x = pd.Series(x, name = 'Thalach Variable')
ax = sns.kdeplot(x)
plt.show()

# %%
f, ax = plt.subplots(figsize = (10, 6))
x = df['thalach']
x = pd.Series(x , name = 'thalach variable')
ax = sns.kdeplot(x, shade = True, color = 'r')

# %%
# Histogram.
f, ax = plt.subplots(figsize = (10, 6))
x = df['thalach']
ax = sns.distplot(x, kde=False, bins = 10, rug= True)
plt.show()

# %%
f, ax = plt.subplots(figsize = (8, 6))
ax = sns.stripplot(data = df, x = 'target', y = 'thalach')
plt.show()

# %%
ax = sns.stripplot(data = df, x = 'target', y = 'thalach', jitter= 0.01)

# %%
sns.boxplot(data = df, x = 'target', y = 'thalach')
# Out:
# <Axes: xlabel='target', ylabel='thalach'>

# %%
#heatmap
plt.figure(figsize= (16, 12))
plt.title("corelation heatmap of heart disease dataset")
h = sns.heatmap(corelation, annot= True, square= True, fmt= '.2f', linecolor='white')
h.set_xticklabels(h.get_xticklabels(), rotation=90)
h.set_yticklabels(h.get_yticklabels(), rotation=30)           
plt.show()

# %%
nums = ['age', 'trestbps', 'chol', 'thalach', 'oldpeak', 'target' ]
sns.pairplot(data = df[nums], kind = 'scatter', diag_kind= 'hist')
plt.show()

# %%
df['age'].unique()
# Out:
# array([63, 37, 41, 56, 57, 44, 52, 54, 48, 49, 64, 58, 50, 66, 43, 69, 59,
#        42, 61, 40, 71, 51, 65, 53, 46, 45, 39, 47, 62, 34, 35, 29, 55, 60,
#        67, 68, 74, 76, 70, 38, 77], dtype=int64)

# %%
df['age'].describe()
# Out:
# count    303.000000
# mean      54.366337
# std        9.082101
# min       29.000000
# 25%       47.500000
# 50%       55.000000
# 75%       61.000000
# max       77.000000
# Name: age, dtype: float64

# %%
sns.distplot(df['age'])
# Out:
# <Axes: xlabel='age', ylabel='Density'>

# %%
# Frequency Distribution of 'age' wrt 'target'
sns.stripplot(data = df, x = 'target', y = 'age')
# Out:
# <Axes: xlabel='target', ylabel='age'>

# %%
sns.stripplot(data = df, x = 'target', y = 'age', jitter = 0.01)
# Out:
# <Axes: xlabel='target', ylabel='age'>

# %%
# Boxplot
sns.boxplot(data = df, x = 'target', y = 'age')
# Out:
# <Axes: xlabel='target', ylabel='age'>

# %%
# 'age' and 'trestbps' analysis
sns.lmplot(data = df, x = 'age', y = 'trestbps',hue = 'sex', fit_reg = 'true')

# %%
# Regplot
sns.regplot(data = df, x = 'age', y = 'trestbps')
# Out:
# <Axes: xlabel='age', ylabel='trestbps'>

# %%
# 'age' and 'chol' analysis
sns.scatterplot(data = df, x = 'age', y = 'chol')
# Out:
# <Axes: xlabel='age', ylabel='chol'>

# %%
sns.regplot(data =df, x = 'age', y = 'chol')
# Out:
# <Axes: xlabel='age', ylabel='chol'>

# %%
sns.scatterplot(data = df, x = 'chol',y = 'thalach')
# Out:
# <Axes: xlabel='chol', ylabel='thalach'>

# %%
sns.regplot(data = df, x = 'chol', y = 'thalach')
# Out:
# <Axes: xlabel='chol', ylabel='thalach'>

# %% [markdown]
# # Checking Missing Values

# %%
df.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# 0

# %%
df.isnull().any()
# Out:
# age         False
# sex         False
# cp          False
# trestbps    False
# chol        False
# fbs         False
# restecg     False
# thalach     False
# exang       False
# oldpeak     False
# slope       False
# ca          False
# thal        False
# target      False
# dtype: bool

# %%
df.isnull().any().any()
# Out:
# False

# %%
df.isnull().values.any()
# Out:
# False

# %%
# Assert Statement--> Return nothing is true, else will throw an AssertionError

assert pd.notnull(df).all().all()

# %%
assert (df >= 0).all().all()

# %% [markdown]
# # Outlier detection

# %%
df['age'].describe()
# Out:
# count    303.000000
# mean      54.366337
# std        9.082101
# min       29.000000
# 25%       47.500000
# 50%       55.000000
# 75%       61.000000
# max       77.000000
# Name: age, dtype: float64

# %%
sns.boxplot(df['age'])
# Out:
# <Axes: ylabel='age'>

# %%
df['thalach'].describe()
# Out:
# count    303.000000
# mean     149.646865
# std       22.905161
# min       71.000000
# 25%      133.500000
# 50%      153.000000
# 75%      166.000000
# max      202.000000
# Name: thalach, dtype: float64

# %%
sns.boxplot(df.thalach)
# Out:
# <Axes: ylabel='thalach'>

# %%
df.chol.describe()
# Out:
# count    303.000000
# mean     246.264026
# std       51.830751
# min      126.000000
# 25%      211.000000
# 50%      240.000000
# 75%      274.500000
# max      564.000000
# Name: chol, dtype: float64

# %%
sns.boxplot(df.chol)
# Out:
# <Axes: ylabel='chol'>

# %%
df.trestbps.describe()
# Out:
# count    303.000000
# mean     131.623762
# std       17.538143
# min       94.000000
# 25%      120.000000
# 50%      130.000000
# 75%      140.000000
# max      200.000000
# Name: trestbps, dtype: float64

# %%
sns.boxplot(df.trestbps)
# Out:
# <Axes: ylabel='trestbps'>

# %%
df.oldpeak.describe()
# Out:
# count    303.000000
# mean       1.039604
# std        1.161075
# min        0.000000
# 25%        0.000000
# 50%        0.800000
# 75%        1.600000
# max        6.200000
# Name: oldpeak, dtype: float64

# %%
sns.boxplot(df.oldpeak)
# Out:
# <Axes: ylabel='oldpeak'>
